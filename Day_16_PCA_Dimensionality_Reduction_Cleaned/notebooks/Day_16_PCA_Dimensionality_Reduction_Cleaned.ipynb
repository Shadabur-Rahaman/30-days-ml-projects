# %% [markdown]
# <a href="https://colab.research.google.com/github/Shadabur-Rahaman/30-days-ml-projects/blob/main/Day_16_PCA_Dimensionality_Reduction_Cleaned/notebooks/Day_16_PCA_Dimensionality_Reduction_Cleaned.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📘 Day 16: PCA for Dimensionality Reduction
#
# **Principal Component Analysis (PCA)** is a powerful technique to reduce the dimensionality of large datasets while preserving most of the variance.
#
# **Goal:** Use PCA on high‑dimensional data and visualize the first two principal components.
#
# We'll work with the classic **Digits** dataset and project it into 2D.
#
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.datasets import load_digits
from sklearn.preprocessing import StandardScaler
from mpl_toolkits.mplot3d import Axes3D  # For 3D plotting

# %% [markdown]
# ## 🔢 Load and Scale the Data

# %%
digits = load_digits()
X = digits.data
y = digits.target

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ## 📉 Apply PCA to Reduce Dimensions

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

print(f"Original shape: {X.shape}")
print(f"Reduced shape: {X_pca.shape}")
# Out:
# Original shape: (1797, 64)
# Reduced shape: (1797, 2)

# %% [markdown]
# ## 🎨 Visualize PCA Components

# %%
plt.figure(figsize=(10, 6))
scatter = plt.scatter(
    X_pca[:, 0], X_pca[:, 1],
    c=y,
    cmap='tab10',
    alpha=0.7
)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA Projection of Digits Dataset')
plt.legend(
    *scatter.legend_elements(),
    title="Digit",
    bbox_to_anchor=(1.05, 1),
    loc='upper left'
)
plt.tight_layout()
plt.show()

# %%
# 📊 Explained Variance Ratio Plot
plt.figure(figsize=(8, 4))
components = [f'PC{i+1}' for i in range(3)]
plt.bar(components, pca_3d.explained_variance_ratio_, color='skyblue')
plt.xlabel('Principal Components')
plt.ylabel('Explained Variance Ratio')
plt.title('Explained Variance Ratio of First 3 PCA Components')
plt.tight_layout()
plt.savefig("explained_variance_ratio.png")
plt.show()

# %%
pca_2d = PCA(n_components=2)
X_pca_2d = pca_2d.fit_transform(X_scaled)

# %%
# 🎨 2D PCA Visualization
plt.figure(figsize=(10, 6))
scatter = plt.scatter(X_pca_2d[:, 0], X_pca_2d[:, 1], c=y, cmap='tab10', alpha=0.7)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA 2D Projection of Digits Dataset')
plt.legend(*scatter.legend_elements(), title="Digit", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.savefig("pca_2d_projection.png")
plt.show()

# %%
# 3D PCA transformation
pca_3d = PCA(n_components=3)
X_pca_3d = pca_3d.fit_transform(X_scaled)

# %%
# 🔺 3D PCA Visualization
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(X_pca_3d[:, 0], X_pca_3d[:, 1], X_pca_3d[:, 2], c=y, cmap='tab10', alpha=0.6)
ax.set_xlabel('PC 1')
ax.set_ylabel('PC 2')
ax.set_zlabel('PC 3')
plt.title('PCA 3D Projection of Digits Dataset')
plt.legend(*scatter.legend_elements(), title="Digit", bbox_to_anchor=(1.1, 1), loc='upper left')
plt.tight_layout()
plt.savefig("pca_3d_projection.png")
plt.show()

# %% [markdown]
# ## ✅ Summary
#
# - PCA reduces dimensions while preserving maximum variance.
# - A 2D PCA projection often reveals clusters corresponding to different digit classes.
# - Useful for visualization and as a pre‑processing step before classification.
#
# *Tip:* Try changing `n_components` or applying PCA before feeding data into other models!
